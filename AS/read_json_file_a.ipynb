# %%
df_fruits = spark.read.option("multiline", "true").json("/FileStore/tables/fruits.json")

display(df_fruits)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>fruit</th><th>size</th></tr></thead><tbody><tr><td>Red</td><td>Apple</td><td>Large</td></tr><tr><td>Yellow</td><td>Mango</td><td>Large</td></tr><tr><td>Red</td><td>Cherry</td><td>Small</td></tr><tr><td>Green</td><td>watermelon</td><td>Large</td></tr><tr><td>Orange</td><td>Orange</td><td>Large</td></tr></tbody></table></div>
